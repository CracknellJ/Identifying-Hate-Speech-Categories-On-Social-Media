# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, plot_confusion_matrix
import nltk

import pickle

# %%
#Load in data and split for train and test sets
df = pd.read_csv(r'C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Data\clean_dataset.csv')
X_train, X_test, y_train, y_test = train_test_split(df['text_lemma'], df['Hate'], test_size=0.25, random_state=12)
                                                       
df.head(5)
# Out:
#              id                                               text Annotation  \
# 0  5.969655e+17  i just found the perfect rental why cant my le...    Neither
# 1  5.758918e+17   every time they discover anything its either ...    Neither
# 2  5.952595e+17    ok time to write code bbl\n\nmaking a new thing    Neither
# 3  5.723449e+17                            refined dessert not mkr    Neither
# 4  5.681320e+17    one of the best things anyone can do to impr...    Neither
#
#                                       tokenized_text  \
# 0  ['found', 'perfect', 'rental', 'cant', 'lease'...
# 1  ['every', 'time', 'discover', 'anything', 'eit...
# 2  ['ok', 'time', 'write', 'code', 'bbl', 'making...
# 3                      ['refined', 'dessert', 'mkr']
# 4  ['one', 'best', 'things', 'anyone', 'improve',...
#
#                                           text_lemma  \
# 0  ['found', 'perfect', 'rental', 'cant', 'lease'...
# 1  ['every', 'time', 'discover', 'anything', 'eit...
# 2  ['ok', 'time', 'write', 'code', 'bbl', 'making...
# 3                      ['refined', 'dessert', 'mkr']
# 4  ['one', 'best', 'thing', 'anyone', 'improve', ...
#
#                                             pos_tags  Hate
# 0  ['i_NN', 'just_RB', 'found_VBD', 'the_DT', 'pe...     0
# 1  ['every_DT', 'time_NN', 'they_PRP', 'discover_...     0
# 2  ['ok_JJ', 'time_NN', 'to_TO', 'write_VB', 'cod...     0
# 3  ['refined_VBN', 'dessert_NN', 'not_RB', 'mkr_VB']     0
# 4  ['one_CD', 'of_IN', 'the_DT', 'best_JJS', 'thi...     0

# %%
#create Count matrix
count = CountVectorizer()
count_train = count.fit_transform(X_train)
count_test = count.transform(X_test)

# %% [markdown]
# ## Default NB

# %%
default_NB = GaussianNB(var_smoothing=1e-9)

# %%
# train classifier
print("training...")
default_NB.fit(count_train.toarray(), y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
default_NB_test_preds = default_NB.predict(count_test.toarray())
print("complete.")

# save the model to disk
filename = 'default_NB.sav'
pickle.dump(default_NB, open(filename, 'wb'))
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
NB_metrics = {}
default_NB_precision = precision_score(y_test, default_NB_test_preds)
default_NB_recall = recall_score(y_test, default_NB_test_preds)
default_NB_f1_score = f1_score(y_test, default_NB_test_preds)
default_NB_weighted_f1_score = f1_score(y_test, default_NB_test_preds, average='weighted')
default_NB_macro_f1_score = f1_score(y_test, default_NB_test_preds, average='macro')
default_NB_micro_f1_score = f1_score(y_test, default_NB_test_preds, average='micro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(default_NB_precision))
print('Recall: {:.3}'.format(default_NB_recall))
print('F1 Score: {:.3}'.format(default_NB_f1_score))
print('Weighted F1 Score: {:.3}'.format(default_NB_weighted_f1_score))
print('Macro F1 Score: {:.3}'.format(default_NB_macro_f1_score))
print('Micro F1 Score: {:.3}'.format(default_NB_micro_f1_score))

NB_metrics['Default NB'] = {'precision': default_NB_precision, 'recall': default_NB_recall, 
                            'f1_score': default_NB_f1_score, 'weighted_f1': default_NB_weighted_f1_score,
                            'macro_f1': default_NB_macro_f1_score, 'micro_f1': default_NB_micro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.307
# Recall: 0.581
# F1 Score: 0.402
# Weighted F1 Score: 0.75
# Macro F1 Score: 0.609
# Micro F1 Score: 0.72

# %%
plot_confusion_matrix(default_NB, count_test.toarray(), y_test)

# %% [markdown]
# ## Grid NB

# %%
grid_NB = GaussianNB()

grid_search_params = {'var_smoothing': np.logspace(0,-9, num=100)}
grid_NB = GridSearchCV(grid_NB, grid_search_params, cv=5, scoring='f1', verbose=3)

grid_NB.fit(count_train.toarray(), y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] var_smoothing=1.0 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... var_smoothing=1.0, score=0.580, total=   1.1s
# [CV] var_smoothing=1.0 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV] ................... var_smoothing=1.0, score=0.581, total=   1.0s
# [CV] var_smoothing=1.0 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [CV] ................... var_smoothing=1.0, score=0.433, total=   1.0s
# [CV] var_smoothing=1.0 ...............................................
# [CV] ................... var_smoothing=1.0, score=0.626, total=   1.0s
# [CV] var_smoothing=1.0 ...............................................
# [CV] ................... var_smoothing=1.0, score=0.601, total=   1.0s
# [CV] var_smoothing=0.8111308307896871 ................................
# [CV] .... var_smoothing=0.8111308307896871, score=0.627, total=   1.0s
# [CV] var_smoothing=0.8111308307896871 ................................
# [CV] .... var_smoothing=0.8111308307896871, score=0.593, total=   1.1s
# [CV] var_smoothing=0.8111308307896871 ................................
# [CV] .... var_smoothing=0.8111308307896871, score=0.564, total=   1.0s
# [CV] var_smoothing=0.8111308307896871 ................................
# [CV] .... var_smoothing=0.8111308307896871, score=0.632, total=   1.0s
# [CV] var_smoothing=0.8111308307896871 ................................
# [CV] .... var_smoothing=0.8111308307896871, score=0.629, total=   1.0s
# [CV] var_smoothing=0.657933224657568 .................................
# [CV] ..... var_smoothing=0.657933224657568, score=0.677, total=   1.0s
# [CV] var_smoothing=0.657933224657568 .................................
# [CV] ..... var_smoothing=0.657933224657568, score=0.601, total=   1.0s
# [CV] var_smoothing=0.657933224657568 .................................
# [CV] ..... var_smoothing=0.657933224657568, score=0.606, total=   1.0s
# [CV] var_smoothing=0.657933224657568 .................................
# [CV] ..... var_smoothing=0.657933224657568, score=0.642, total=   1.0s
# [CV] var_smoothing=0.657933224657568 .................................
# [CV] ..... var_smoothing=0.657933224657568, score=0.636, total=   1.0s
# [CV] var_smoothing=0.533669923120631 .................................
# [CV] ..... var_smoothing=0.533669923120631, score=0.667, total=   1.0s
# [CV] var_smoothing=0.533669923120631 .................................
# [CV] ..... var_smoothing=0.533669923120631, score=0.661, total=   1.0s
# [CV] var_smoothing=0.533669923120631 .................................
# [CV] ..... var_smoothing=0.533669923120631, score=0.646, total=   1.0s
# [CV] var_smoothing=0.533669923120631 .................................
# [CV] ..... var_smoothing=0.533669923120631, score=0.645, total=   1.0s
# [CV] var_smoothing=0.533669923120631 .................................
# [CV] ..... var_smoothing=0.533669923120631, score=0.639, total=   1.0s
# [CV] var_smoothing=0.43287612810830584 ...............................
# [CV] ... var_smoothing=0.43287612810830584, score=0.645, total=   1.0s
# [CV] var_smoothing=0.43287612810830584 ...............................
# [CV] ... var_smoothing=0.43287612810830584, score=0.640, total=   1.0s
# [CV] var_smoothing=0.43287612810830584 ...............................
# [CV] ... var_smoothing=0.43287612810830584, score=0.648, total=   1.0s
# [CV] var_smoothing=0.43287612810830584 ...............................
# [CV] ... var_smoothing=0.43287612810830584, score=0.637, total=   1.0s
# [CV] var_smoothing=0.43287612810830584 ...............................
# [CV] ... var_smoothing=0.43287612810830584, score=0.587, total=   1.0s
# [CV] var_smoothing=0.3511191734215131 ................................
# [CV] .... var_smoothing=0.3511191734215131, score=0.637, total=   1.1s
# [CV] var_smoothing=0.3511191734215131 ................................
# [CV] .... var_smoothing=0.3511191734215131, score=0.638, total=   1.0s
# [CV] var_smoothing=0.3511191734215131 ................................
# [CV] .... var_smoothing=0.3511191734215131, score=0.635, total=   1.0s
# [CV] var_smoothing=0.3511191734215131 ................................
# [CV] .... var_smoothing=0.3511191734215131, score=0.623, total=   1.0s
# [CV] var_smoothing=0.3511191734215131 ................................
# [CV] .... var_smoothing=0.3511191734215131, score=0.545, total=   1.0s
# [CV] var_smoothing=0.2848035868435802 ................................
# [CV] .... var_smoothing=0.2848035868435802, score=0.560, total=   1.0s
# [CV] var_smoothing=0.2848035868435802 ................................
# [CV] .... var_smoothing=0.2848035868435802, score=0.610, total=   1.0s
# [CV] var_smoothing=0.2848035868435802 ................................
# [CV] .... var_smoothing=0.2848035868435802, score=0.628, total=   1.0s
# [CV] var_smoothing=0.2848035868435802 ................................
# [CV] .... var_smoothing=0.2848035868435802, score=0.573, total=   1.0s
# [CV] var_smoothing=0.2848035868435802 ................................
# [CV] .... var_smoothing=0.2848035868435802, score=0.484, total=   1.1s
# [CV] var_smoothing=0.23101297000831597 ...............................
# [CV] ... var_smoothing=0.23101297000831597, score=0.494, total=   1.0s
# [CV] var_smoothing=0.23101297000831597 ...............................
# [CV] ... var_smoothing=0.23101297000831597, score=0.586, total=   1.0s
# [CV] var_smoothing=0.23101297000831597 ...............................
# [CV] ... var_smoothing=0.23101297000831597, score=0.593, total=   1.0s
# [CV] var_smoothing=0.23101297000831597 ...............................
# [CV] ... var_smoothing=0.23101297000831597, score=0.511, total=   1.0s
# [CV] var_smoothing=0.23101297000831597 ...............................
# [CV] ... var_smoothing=0.23101297000831597, score=0.448, total=   1.0s
# [CV] var_smoothing=0.1873817422860384 ................................
# [CV] .... var_smoothing=0.1873817422860384, score=0.462, total=   1.0s
# [CV] var_smoothing=0.1873817422860384 ................................
# [CV] .... var_smoothing=0.1873817422860384, score=0.547, total=   1.0s
# [CV] var_smoothing=0.1873817422860384 ................................
# [CV] .... var_smoothing=0.1873817422860384, score=0.562, total=   1.0s
# [CV] var_smoothing=0.1873817422860384 ................................
# [CV] .... var_smoothing=0.1873817422860384, score=0.473, total=   1.0s
# [CV] var_smoothing=0.1873817422860384 ................................
# [CV] .... var_smoothing=0.1873817422860384, score=0.422, total=   1.0s
# [CV] var_smoothing=0.15199110829529336 ...............................
# [CV] ... var_smoothing=0.15199110829529336, score=0.435, total=   1.0s
# [CV] var_smoothing=0.15199110829529336 ...............................
# [CV] ... var_smoothing=0.15199110829529336, score=0.491, total=   1.0s
# [CV] var_smoothing=0.15199110829529336 ...............................
# [CV] ... var_smoothing=0.15199110829529336, score=0.526, total=   1.0s
# [CV] var_smoothing=0.15199110829529336 ...............................
# [CV] ... var_smoothing=0.15199110829529336, score=0.443, total=   1.0s
# [CV] var_smoothing=0.15199110829529336 ...............................
# [CV] ... var_smoothing=0.15199110829529336, score=0.408, total=   1.0s
# [CV] var_smoothing=0.12328467394420659 ...............................
# [CV] ... var_smoothing=0.12328467394420659, score=0.412, total=   1.0s
# [CV] var_smoothing=0.12328467394420659 ...............................
# [CV] ... var_smoothing=0.12328467394420659, score=0.475, total=   1.0s
# [CV] var_smoothing=0.12328467394420659 ...............................
# [CV] ... var_smoothing=0.12328467394420659, score=0.498, total=   1.0s
# [CV] var_smoothing=0.12328467394420659 ...............................
# [CV] ... var_smoothing=0.12328467394420659, score=0.427, total=   1.0s
# [CV] var_smoothing=0.12328467394420659 ...............................
# [CV] ... var_smoothing=0.12328467394420659, score=0.399, total=   1.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.402, total=   1.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.455, total=   1.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.472, total=   1.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.416, total=   1.0s
# [CV] var_smoothing=0.1 ...............................................
# [CV] ................... var_smoothing=0.1, score=0.388, total=   1.0s
# [CV] var_smoothing=0.08111308307896872 ...............................
# [CV] ... var_smoothing=0.08111308307896872, score=0.395, total=   1.1s
# [CV] var_smoothing=0.08111308307896872 ...............................
# [CV] ... var_smoothing=0.08111308307896872, score=0.439, total=   1.0s
# [CV] var_smoothing=0.08111308307896872 ...............................
# [CV] ... var_smoothing=0.08111308307896872, score=0.453, total=   1.0s
# [CV] var_smoothing=0.08111308307896872 ...............................
# [CV] ... var_smoothing=0.08111308307896872, score=0.403, total=   1.0s
# [CV] var_smoothing=0.08111308307896872 ...............................
# [CV] ... var_smoothing=0.08111308307896872, score=0.381, total=   1.0s
# [CV] var_smoothing=0.0657933224657568 ................................
# [CV] .... var_smoothing=0.0657933224657568, score=0.388, total=   1.0s
# [CV] var_smoothing=0.0657933224657568 ................................
# [CV] .... var_smoothing=0.0657933224657568, score=0.430, total=   1.0s
# [CV] var_smoothing=0.0657933224657568 ................................
# [CV] .... var_smoothing=0.0657933224657568, score=0.436, total=   1.0s
# [CV] var_smoothing=0.0657933224657568 ................................
# [CV] .... var_smoothing=0.0657933224657568, score=0.397, total=   1.0s
# [CV] var_smoothing=0.0657933224657568 ................................
# [CV] .... var_smoothing=0.0657933224657568, score=0.376, total=   1.0s
# [CV] var_smoothing=0.0533669923120631 ................................
# [CV] .... var_smoothing=0.0533669923120631, score=0.389, total=   1.0s
# [CV] var_smoothing=0.0533669923120631 ................................
# [CV] .... var_smoothing=0.0533669923120631, score=0.419, total=   1.0s
# [CV] var_smoothing=0.0533669923120631 ................................
# [CV] .... var_smoothing=0.0533669923120631, score=0.436, total=   1.0s
# [CV] var_smoothing=0.0533669923120631 ................................
# [CV] .... var_smoothing=0.0533669923120631, score=0.395, total=   1.0s
# [CV] var_smoothing=0.0533669923120631 ................................
# [CV] .... var_smoothing=0.0533669923120631, score=0.375, total=   0.9s
# [CV] var_smoothing=0.04328761281083057 ...............................
# [CV] ... var_smoothing=0.04328761281083057, score=0.384, total=   1.0s
# [CV] var_smoothing=0.04328761281083057 ...............................
# [CV] ... var_smoothing=0.04328761281083057, score=0.415, total=   1.0s
# [CV] var_smoothing=0.04328761281083057 ...............................
# [CV] ... var_smoothing=0.04328761281083057, score=0.419, total=   1.0s
# [CV] var_smoothing=0.04328761281083057 ...............................
# [CV] ... var_smoothing=0.04328761281083057, score=0.393, total=   1.0s
# [CV] var_smoothing=0.04328761281083057 ...............................
# [CV] ... var_smoothing=0.04328761281083057, score=0.380, total=   1.0s
# [CV] var_smoothing=0.03511191734215131 ...............................
# [CV] ... var_smoothing=0.03511191734215131, score=0.383, total=   1.0s
# [CV] var_smoothing=0.03511191734215131 ...............................
# [CV] ... var_smoothing=0.03511191734215131, score=0.405, total=   1.0s
# [CV] var_smoothing=0.03511191734215131 ...............................
# [CV] ... var_smoothing=0.03511191734215131, score=0.416, total=   1.0s
# [CV] var_smoothing=0.03511191734215131 ...............................
# [CV] ... var_smoothing=0.03511191734215131, score=0.386, total=   1.0s
# [CV] var_smoothing=0.03511191734215131 ...............................
# [CV] ... var_smoothing=0.03511191734215131, score=0.384, total=   1.0s
# [CV] var_smoothing=0.02848035868435802 ...............................
# [CV] ... var_smoothing=0.02848035868435802, score=0.387, total=   1.0s
# [CV] var_smoothing=0.02848035868435802 ...............................
# [CV] ... var_smoothing=0.02848035868435802, score=0.405, total=   1.0s
# [CV] var_smoothing=0.02848035868435802 ...............................
# [CV] ... var_smoothing=0.02848035868435802, score=0.398, total=   1.0s
# [CV] var_smoothing=0.02848035868435802 ...............................
# [CV] ... var_smoothing=0.02848035868435802, score=0.387, total=   1.0s
# [CV] var_smoothing=0.02848035868435802 ...............................
# [CV] ... var_smoothing=0.02848035868435802, score=0.386, total=   1.0s
# [CV] var_smoothing=0.02310129700083159 ...............................
# [CV] ... var_smoothing=0.02310129700083159, score=0.384, total=   1.0s
# [CV] var_smoothing=0.02310129700083159 ...............................
# [CV] ... var_smoothing=0.02310129700083159, score=0.401, total=   1.0s
# [CV] var_smoothing=0.02310129700083159 ...............................
# [CV] ... var_smoothing=0.02310129700083159, score=0.391, total=   1.0s
# [CV] var_smoothing=0.02310129700083159 ...............................
# [CV] ... var_smoothing=0.02310129700083159, score=0.380, total=   1.0s
# [CV] var_smoothing=0.02310129700083159 ...............................
# [CV] ... var_smoothing=0.02310129700083159, score=0.381, total=   0.9s
# [CV] var_smoothing=0.01873817422860384 ...............................
# [CV] ... var_smoothing=0.01873817422860384, score=0.385, total=   1.0s
# [CV] var_smoothing=0.01873817422860384 ...............................
# [CV] ... var_smoothing=0.01873817422860384, score=0.400, total=   1.0s
# [CV] var_smoothing=0.01873817422860384 ...............................
# [CV] ... var_smoothing=0.01873817422860384, score=0.388, total=   1.0s
# [CV] var_smoothing=0.01873817422860384 ...............................
# [CV] ... var_smoothing=0.01873817422860384, score=0.382, total=   1.0s
# [CV] var_smoothing=0.01873817422860384 ...............................
# [CV] ... var_smoothing=0.01873817422860384, score=0.380, total=   1.0s
# [CV] var_smoothing=0.01519911082952933 ...............................
# [CV] ... var_smoothing=0.01519911082952933, score=0.379, total=   1.0s
# [CV] var_smoothing=0.01519911082952933 ...............................
# [CV] ... var_smoothing=0.01519911082952933, score=0.396, total=   1.0s
# [CV] var_smoothing=0.01519911082952933 ...............................
# [CV] ... var_smoothing=0.01519911082952933, score=0.388, total=   1.0s
# [CV] var_smoothing=0.01519911082952933 ...............................
# [CV] ... var_smoothing=0.01519911082952933, score=0.379, total=   1.0s
# [CV] var_smoothing=0.01519911082952933 ...............................
# [CV] ... var_smoothing=0.01519911082952933, score=0.379, total=   1.0s
# [CV] var_smoothing=0.012328467394420659 ..............................
# [CV] .. var_smoothing=0.012328467394420659, score=0.375, total=   1.0s
# [CV] var_smoothing=0.012328467394420659 ..............................
# [CV] .. var_smoothing=0.012328467394420659, score=0.406, total=   1.0s
# [CV] var_smoothing=0.012328467394420659 ..............................
# [CV] .. var_smoothing=0.012328467394420659, score=0.390, total=   1.0s
# [CV] var_smoothing=0.012328467394420659 ..............................
# [CV] .. var_smoothing=0.012328467394420659, score=0.380, total=   1.0s
# [CV] var_smoothing=0.012328467394420659 ..............................
# [CV] .. var_smoothing=0.012328467394420659, score=0.374, total=   1.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.375, total=   1.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.406, total=   1.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.385, total=   1.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.382, total=   1.0s
# [CV] var_smoothing=0.01 ..............................................
# [CV] .................. var_smoothing=0.01, score=0.369, total=   1.0s
# [CV] var_smoothing=0.008111308307896872 ..............................
# [CV] .. var_smoothing=0.008111308307896872, score=0.379, total=   1.0s
# [CV] var_smoothing=0.008111308307896872 ..............................
# [CV] .. var_smoothing=0.008111308307896872, score=0.410, total=   1.0s
# [CV] var_smoothing=0.008111308307896872 ..............................
# [CV] .. var_smoothing=0.008111308307896872, score=0.387, total=   1.0s
# [CV] var_smoothing=0.008111308307896872 ..............................
# [CV] .. var_smoothing=0.008111308307896872, score=0.386, total=   1.0s
# [CV] var_smoothing=0.008111308307896872 ..............................
# [CV] .. var_smoothing=0.008111308307896872, score=0.369, total=   1.0s
# [CV] var_smoothing=0.006579332246575682 ..............................
# [CV] .. var_smoothing=0.006579332246575682, score=0.379, total=   1.0s
# [CV] var_smoothing=0.006579332246575682 ..............................
# [CV] .. var_smoothing=0.006579332246575682, score=0.415, total=   1.1s
# [CV] var_smoothing=0.006579332246575682 ..............................
# [CV] .. var_smoothing=0.006579332246575682, score=0.378, total=   1.0s
# [CV] var_smoothing=0.006579332246575682 ..............................
# [CV] .. var_smoothing=0.006579332246575682, score=0.392, total=   1.0s
# [CV] var_smoothing=0.006579332246575682 ..............................
# [CV] .. var_smoothing=0.006579332246575682, score=0.374, total=   1.0s
# [CV] var_smoothing=0.005336699231206307 ..............................
# [CV] .. var_smoothing=0.005336699231206307, score=0.388, total=   1.0s
# [CV] var_smoothing=0.005336699231206307 ..............................
# [CV] .. var_smoothing=0.005336699231206307, score=0.418, total=   1.0s
# [CV] var_smoothing=0.005336699231206307 ..............................
# [CV] .. var_smoothing=0.005336699231206307, score=0.380, total=   1.0s
# [CV] var_smoothing=0.005336699231206307 ..............................
# [CV] .. var_smoothing=0.005336699231206307, score=0.394, total=   1.0s
# [CV] var_smoothing=0.005336699231206307 ..............................
# [CV] .. var_smoothing=0.005336699231206307, score=0.378, total=   1.0s
# [CV] var_smoothing=0.004328761281083057 ..............................
# [CV] .. var_smoothing=0.004328761281083057, score=0.384, total=   1.0s
# [CV] var_smoothing=0.004328761281083057 ..............................
# [CV] .. var_smoothing=0.004328761281083057, score=0.422, total=   1.0s
# [CV] var_smoothing=0.004328761281083057 ..............................
# [CV] .. var_smoothing=0.004328761281083057, score=0.386, total=   1.0s
# [CV] var_smoothing=0.004328761281083057 ..............................
# [CV] .. var_smoothing=0.004328761281083057, score=0.384, total=   1.0s
# [CV] var_smoothing=0.004328761281083057 ..............................
# [CV] .. var_smoothing=0.004328761281083057, score=0.379, total=   1.0s
# [CV] var_smoothing=0.003511191734215131 ..............................
# [CV] .. var_smoothing=0.003511191734215131, score=0.383, total=   1.0s
# [CV] var_smoothing=0.003511191734215131 ..............................
# [CV] .. var_smoothing=0.003511191734215131, score=0.427, total=   1.0s
# [CV] var_smoothing=0.003511191734215131 ..............................
# [CV] .. var_smoothing=0.003511191734215131, score=0.395, total=   1.0s
# [CV] var_smoothing=0.003511191734215131 ..............................
# [CV] .. var_smoothing=0.003511191734215131, score=0.373, total=   1.0s
# [CV] var_smoothing=0.003511191734215131 ..............................
# [CV] .. var_smoothing=0.003511191734215131, score=0.382, total=   1.0s
# [CV] var_smoothing=0.002848035868435802 ..............................
# [CV] .. var_smoothing=0.002848035868435802, score=0.387, total=   1.0s
# [CV] var_smoothing=0.002848035868435802 ..............................
# [CV] .. var_smoothing=0.002848035868435802, score=0.431, total=   1.0s
# [CV] var_smoothing=0.002848035868435802 ..............................
# [CV] .. var_smoothing=0.002848035868435802, score=0.400, total=   1.0s
# [CV] var_smoothing=0.002848035868435802 ..............................
# [CV] .. var_smoothing=0.002848035868435802, score=0.374, total=   1.0s
# [CV] var_smoothing=0.002848035868435802 ..............................
# [CV] .. var_smoothing=0.002848035868435802, score=0.385, total=   1.0s
# [CV] var_smoothing=0.0023101297000831605 .............................
# [CV] . var_smoothing=0.0023101297000831605, score=0.377, total=   1.0s
# [CV] var_smoothing=0.0023101297000831605 .............................
# [CV] . var_smoothing=0.0023101297000831605, score=0.439, total=   1.0s
# [CV] var_smoothing=0.0023101297000831605 .............................
# [CV] . var_smoothing=0.0023101297000831605, score=0.416, total=   1.0s
# [CV] var_smoothing=0.0023101297000831605 .............................
# [CV] . var_smoothing=0.0023101297000831605, score=0.379, total=   1.0s
# [CV] var_smoothing=0.0023101297000831605 .............................
# [CV] . var_smoothing=0.0023101297000831605, score=0.389, total=   1.1s
# [CV] var_smoothing=0.001873817422860383 ..............................
# [CV] .. var_smoothing=0.001873817422860383, score=0.383, total=   1.2s
# [CV] var_smoothing=0.001873817422860383 ..............................
# [CV] .. var_smoothing=0.001873817422860383, score=0.436, total=   1.1s
# [CV] var_smoothing=0.001873817422860383 ..............................
# [CV] .. var_smoothing=0.001873817422860383, score=0.417, total=   1.0s
# [CV] var_smoothing=0.001873817422860383 ..............................
# [CV] .. var_smoothing=0.001873817422860383, score=0.384, total=   1.0s
# [CV] var_smoothing=0.001873817422860383 ..............................
# [CV] .. var_smoothing=0.001873817422860383, score=0.396, total=   1.1s
# [CV] var_smoothing=0.0015199110829529332 .............................
# [CV] . var_smoothing=0.0015199110829529332, score=0.404, total=   1.0s
# [CV] var_smoothing=0.0015199110829529332 .............................
# [CV] . var_smoothing=0.0015199110829529332, score=0.438, total=   1.1s
# [CV] var_smoothing=0.0015199110829529332 .............................
# [CV] . var_smoothing=0.0015199110829529332, score=0.412, total=   1.0s
# [CV] var_smoothing=0.0015199110829529332 .............................
# [CV] . var_smoothing=0.0015199110829529332, score=0.386, total=   1.0s
# [CV] var_smoothing=0.0015199110829529332 .............................
# [CV] . var_smoothing=0.0015199110829529332, score=0.394, total=   1.0s
# [CV] var_smoothing=0.0012328467394420659 .............................
# [CV] . var_smoothing=0.0012328467394420659, score=0.390, total=   1.0s
# [CV] var_smoothing=0.0012328467394420659 .............................
# [CV] . var_smoothing=0.0012328467394420659, score=0.427, total=   1.0s
# [CV] var_smoothing=0.0012328467394420659 .............................
# [CV] . var_smoothing=0.0012328467394420659, score=0.411, total=   1.0s
# [CV] var_smoothing=0.0012328467394420659 .............................
# [CV] . var_smoothing=0.0012328467394420659, score=0.378, total=   1.0s
# [CV] var_smoothing=0.0012328467394420659 .............................
# [CV] . var_smoothing=0.0012328467394420659, score=0.392, total=   1.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.382, total=   1.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.417, total=   1.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.393, total=   1.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.379, total=   1.0s
# [CV] var_smoothing=0.001 .............................................
# [CV] ................. var_smoothing=0.001, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0008111308307896872 .............................
# [CV] . var_smoothing=0.0008111308307896872, score=0.367, total=   1.0s
# [CV] var_smoothing=0.0008111308307896872 .............................
# [CV] . var_smoothing=0.0008111308307896872, score=0.417, total=   1.0s
# [CV] var_smoothing=0.0008111308307896872 .............................
# [CV] . var_smoothing=0.0008111308307896872, score=0.386, total=   1.0s
# [CV] var_smoothing=0.0008111308307896872 .............................
# [CV] . var_smoothing=0.0008111308307896872, score=0.360, total=   1.0s
# [CV] var_smoothing=0.0008111308307896872 .............................
# [CV] . var_smoothing=0.0008111308307896872, score=0.386, total=   1.0s
# [CV] var_smoothing=0.0006579332246575676 .............................
# [CV] . var_smoothing=0.0006579332246575676, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0006579332246575676 .............................
# [CV] . var_smoothing=0.0006579332246575676, score=0.418, total=   1.0s
# [CV] var_smoothing=0.0006579332246575676 .............................
# [CV] . var_smoothing=0.0006579332246575676, score=0.382, total=   1.0s
# [CV] var_smoothing=0.0006579332246575676 .............................
# [CV] . var_smoothing=0.0006579332246575676, score=0.351, total=   1.0s
# [CV] var_smoothing=0.0006579332246575676 .............................
# [CV] . var_smoothing=0.0006579332246575676, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0005336699231206307 .............................
# [CV] . var_smoothing=0.0005336699231206307, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0005336699231206307 .............................
# [CV] . var_smoothing=0.0005336699231206307, score=0.418, total=   1.0s
# [CV] var_smoothing=0.0005336699231206307 .............................
# [CV] . var_smoothing=0.0005336699231206307, score=0.382, total=   1.0s
# [CV] var_smoothing=0.0005336699231206307 .............................
# [CV] . var_smoothing=0.0005336699231206307, score=0.351, total=   1.0s
# [CV] var_smoothing=0.0005336699231206307 .............................
# [CV] . var_smoothing=0.0005336699231206307, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0004328761281083057 .............................
# [CV] . var_smoothing=0.0004328761281083057, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0004328761281083057 .............................
# [CV] . var_smoothing=0.0004328761281083057, score=0.418, total=   1.0s
# [CV] var_smoothing=0.0004328761281083057 .............................
# [CV] . var_smoothing=0.0004328761281083057, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0004328761281083057 .............................
# [CV] . var_smoothing=0.0004328761281083057, score=0.351, total=   1.0s
# [CV] var_smoothing=0.0004328761281083057 .............................
# [CV] . var_smoothing=0.0004328761281083057, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0003511191734215131 .............................
# [CV] . var_smoothing=0.0003511191734215131, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0003511191734215131 .............................
# [CV] . var_smoothing=0.0003511191734215131, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0003511191734215131 .............................
# [CV] . var_smoothing=0.0003511191734215131, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0003511191734215131 .............................
# [CV] . var_smoothing=0.0003511191734215131, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0003511191734215131 .............................
# [CV] . var_smoothing=0.0003511191734215131, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0002848035868435802 .............................
# [CV] . var_smoothing=0.0002848035868435802, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0002848035868435802 .............................
# [CV] . var_smoothing=0.0002848035868435802, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0002848035868435802 .............................
# [CV] . var_smoothing=0.0002848035868435802, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0002848035868435802 .............................
# [CV] . var_smoothing=0.0002848035868435802, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0002848035868435802 .............................
# [CV] . var_smoothing=0.0002848035868435802, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0002310129700083158 .............................
# [CV] . var_smoothing=0.0002310129700083158, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0002310129700083158 .............................
# [CV] . var_smoothing=0.0002310129700083158, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0002310129700083158 .............................
# [CV] . var_smoothing=0.0002310129700083158, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0002310129700083158 .............................
# [CV] . var_smoothing=0.0002310129700083158, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0002310129700083158 .............................
# [CV] . var_smoothing=0.0002310129700083158, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0001873817422860383 .............................
# [CV] . var_smoothing=0.0001873817422860383, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0001873817422860383 .............................
# [CV] . var_smoothing=0.0001873817422860383, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0001873817422860383 .............................
# [CV] . var_smoothing=0.0001873817422860383, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0001873817422860383 .............................
# [CV] . var_smoothing=0.0001873817422860383, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0001873817422860383 .............................
# [CV] . var_smoothing=0.0001873817422860383, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0001519911082952933 .............................
# [CV] . var_smoothing=0.0001519911082952933, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0001519911082952933 .............................
# [CV] . var_smoothing=0.0001519911082952933, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0001519911082952933 .............................
# [CV] . var_smoothing=0.0001519911082952933, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0001519911082952933 .............................
# [CV] . var_smoothing=0.0001519911082952933, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0001519911082952933 .............................
# [CV] . var_smoothing=0.0001519911082952933, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0001232846739442066 .............................
# [CV] . var_smoothing=0.0001232846739442066, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0001232846739442066 .............................
# [CV] . var_smoothing=0.0001232846739442066, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0001232846739442066 .............................
# [CV] . var_smoothing=0.0001232846739442066, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0001232846739442066 .............................
# [CV] . var_smoothing=0.0001232846739442066, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0001232846739442066 .............................
# [CV] . var_smoothing=0.0001232846739442066, score=0.384, total=   1.0s
# [CV] var_smoothing=0.0001 ............................................
# [CV] ................ var_smoothing=0.0001, score=0.356, total=   1.0s
# [CV] var_smoothing=0.0001 ............................................
# [CV] ................ var_smoothing=0.0001, score=0.415, total=   1.0s
# [CV] var_smoothing=0.0001 ............................................
# [CV] ................ var_smoothing=0.0001, score=0.383, total=   1.0s
# [CV] var_smoothing=0.0001 ............................................
# [CV] ................ var_smoothing=0.0001, score=0.340, total=   1.0s
# [CV] var_smoothing=0.0001 ............................................
# [CV] ................ var_smoothing=0.0001, score=0.384, total=   1.0s
# [CV] var_smoothing=8.111308307896872e-05 .............................
# [CV] . var_smoothing=8.111308307896872e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=8.111308307896872e-05 .............................
# [CV] . var_smoothing=8.111308307896872e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=8.111308307896872e-05 .............................
# [CV] . var_smoothing=8.111308307896872e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=8.111308307896872e-05 .............................
# [CV] . var_smoothing=8.111308307896872e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=8.111308307896872e-05 .............................
# [CV] . var_smoothing=8.111308307896872e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-05 .............................
# [CV] . var_smoothing=6.579332246575683e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-05 .............................
# [CV] . var_smoothing=6.579332246575683e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-05 .............................
# [CV] . var_smoothing=6.579332246575683e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-05 .............................
# [CV] . var_smoothing=6.579332246575683e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-05 .............................
# [CV] . var_smoothing=6.579332246575683e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=5.3366992312063123e-05 ............................
# [CV]  var_smoothing=5.3366992312063123e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=5.3366992312063123e-05 ............................
# [CV]  var_smoothing=5.3366992312063123e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=5.3366992312063123e-05 ............................
# [CV]  var_smoothing=5.3366992312063123e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=5.3366992312063123e-05 ............................
# [CV]  var_smoothing=5.3366992312063123e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=5.3366992312063123e-05 ............................
# [CV]  var_smoothing=5.3366992312063123e-05, score=0.384, total=   1.1s
# [CV] var_smoothing=4.328761281083062e-05 .............................
# [CV] . var_smoothing=4.328761281083062e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=4.328761281083062e-05 .............................
# [CV] . var_smoothing=4.328761281083062e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=4.328761281083062e-05 .............................
# [CV] . var_smoothing=4.328761281083062e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=4.328761281083062e-05 .............................
# [CV] . var_smoothing=4.328761281083062e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=4.328761281083062e-05 .............................
# [CV] . var_smoothing=4.328761281083062e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=3.511191734215127e-05 .............................
# [CV] . var_smoothing=3.511191734215127e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=3.511191734215127e-05 .............................
# [CV] . var_smoothing=3.511191734215127e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=3.511191734215127e-05 .............................
# [CV] . var_smoothing=3.511191734215127e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=3.511191734215127e-05 .............................
# [CV] . var_smoothing=3.511191734215127e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=3.511191734215127e-05 .............................
# [CV] . var_smoothing=3.511191734215127e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-05 .............................
# [CV] . var_smoothing=2.848035868435799e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-05 .............................
# [CV] . var_smoothing=2.848035868435799e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-05 .............................
# [CV] . var_smoothing=2.848035868435799e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-05 .............................
# [CV] . var_smoothing=2.848035868435799e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-05 .............................
# [CV] . var_smoothing=2.848035868435799e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-05 .............................
# [CV] . var_smoothing=2.310129700083158e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-05 .............................
# [CV] . var_smoothing=2.310129700083158e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-05 .............................
# [CV] . var_smoothing=2.310129700083158e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-05 .............................
# [CV] . var_smoothing=2.310129700083158e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-05 .............................
# [CV] . var_smoothing=2.310129700083158e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-05 .............................
# [CV] . var_smoothing=1.873817422860383e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-05 .............................
# [CV] . var_smoothing=1.873817422860383e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-05 .............................
# [CV] . var_smoothing=1.873817422860383e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-05 .............................
# [CV] . var_smoothing=1.873817422860383e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-05 .............................
# [CV] . var_smoothing=1.873817422860383e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=1.5199110829529332e-05 ............................
# [CV]  var_smoothing=1.5199110829529332e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=1.5199110829529332e-05 ............................
# [CV]  var_smoothing=1.5199110829529332e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=1.5199110829529332e-05 ............................
# [CV]  var_smoothing=1.5199110829529332e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=1.5199110829529332e-05 ............................
# [CV]  var_smoothing=1.5199110829529332e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=1.5199110829529332e-05 ............................
# [CV]  var_smoothing=1.5199110829529332e-05, score=0.384, total=   1.1s
# [CV] var_smoothing=1.2328467394420658e-05 ............................
# [CV]  var_smoothing=1.2328467394420658e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=1.2328467394420658e-05 ............................
# [CV]  var_smoothing=1.2328467394420658e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=1.2328467394420658e-05 ............................
# [CV]  var_smoothing=1.2328467394420658e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=1.2328467394420658e-05 ............................
# [CV]  var_smoothing=1.2328467394420658e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=1.2328467394420658e-05 ............................
# [CV]  var_smoothing=1.2328467394420658e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=1e-05 .............................................
# [CV] ................. var_smoothing=1e-05, score=0.356, total=   1.0s
# [CV] var_smoothing=1e-05 .............................................
# [CV] ................. var_smoothing=1e-05, score=0.415, total=   1.0s
# [CV] var_smoothing=1e-05 .............................................
# [CV] ................. var_smoothing=1e-05, score=0.383, total=   1.0s
# [CV] var_smoothing=1e-05 .............................................
# [CV] ................. var_smoothing=1e-05, score=0.340, total=   1.0s
# [CV] var_smoothing=1e-05 .............................................
# [CV] ................. var_smoothing=1e-05, score=0.384, total=   1.0s
# [CV] var_smoothing=8.111308307896873e-06 .............................
# [CV] . var_smoothing=8.111308307896873e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=8.111308307896873e-06 .............................
# [CV] . var_smoothing=8.111308307896873e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=8.111308307896873e-06 .............................
# [CV] . var_smoothing=8.111308307896873e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=8.111308307896873e-06 .............................
# [CV] . var_smoothing=8.111308307896873e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=8.111308307896873e-06 .............................
# [CV] . var_smoothing=8.111308307896873e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-06 .............................
# [CV] . var_smoothing=6.579332246575683e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-06 .............................
# [CV] . var_smoothing=6.579332246575683e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-06 .............................
# [CV] . var_smoothing=6.579332246575683e-06, score=0.383, total=   0.9s
# [CV] var_smoothing=6.579332246575683e-06 .............................
# [CV] . var_smoothing=6.579332246575683e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=6.579332246575683e-06 .............................
# [CV] . var_smoothing=6.579332246575683e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=5.336699231206313e-06 .............................
# [CV] . var_smoothing=5.336699231206313e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=5.336699231206313e-06 .............................
# [CV] . var_smoothing=5.336699231206313e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=5.336699231206313e-06 .............................
# [CV] . var_smoothing=5.336699231206313e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=5.336699231206313e-06 .............................
# [CV] . var_smoothing=5.336699231206313e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=5.336699231206313e-06 .............................
# [CV] . var_smoothing=5.336699231206313e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=4.328761281083053e-06 .............................
# [CV] . var_smoothing=4.328761281083053e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=4.328761281083053e-06 .............................
# [CV] . var_smoothing=4.328761281083053e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=4.328761281083053e-06 .............................
# [CV] . var_smoothing=4.328761281083053e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=4.328761281083053e-06 .............................
# [CV] . var_smoothing=4.328761281083053e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=4.328761281083053e-06 .............................
# [CV] . var_smoothing=4.328761281083053e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=3.5111917342151275e-06 ............................
# [CV]  var_smoothing=3.5111917342151275e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=3.5111917342151275e-06 ............................
# [CV]  var_smoothing=3.5111917342151275e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=3.5111917342151275e-06 ............................
# [CV]  var_smoothing=3.5111917342151275e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=3.5111917342151275e-06 ............................
# [CV]  var_smoothing=3.5111917342151275e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=3.5111917342151275e-06 ............................
# [CV]  var_smoothing=3.5111917342151275e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-06 .............................
# [CV] . var_smoothing=2.848035868435799e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-06 .............................
# [CV] . var_smoothing=2.848035868435799e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-06 .............................
# [CV] . var_smoothing=2.848035868435799e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-06 .............................
# [CV] . var_smoothing=2.848035868435799e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-06 .............................
# [CV] . var_smoothing=2.848035868435799e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-06 .............................
# [CV] . var_smoothing=2.310129700083158e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-06 .............................
# [CV] . var_smoothing=2.310129700083158e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-06 .............................
# [CV] . var_smoothing=2.310129700083158e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-06 .............................
# [CV] . var_smoothing=2.310129700083158e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-06 .............................
# [CV] . var_smoothing=2.310129700083158e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-06 .............................
# [CV] . var_smoothing=1.873817422860383e-06, score=0.356, total=   1.1s
# [CV] var_smoothing=1.873817422860383e-06 .............................
# [CV] . var_smoothing=1.873817422860383e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-06 .............................
# [CV] . var_smoothing=1.873817422860383e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-06 .............................
# [CV] . var_smoothing=1.873817422860383e-06, score=0.340, total=   1.1s
# [CV] var_smoothing=1.873817422860383e-06 .............................
# [CV] . var_smoothing=1.873817422860383e-06, score=0.384, total=   1.1s
# [CV] var_smoothing=1.519911082952933e-06 .............................
# [CV] . var_smoothing=1.519911082952933e-06, score=0.356, total=   1.1s
# [CV] var_smoothing=1.519911082952933e-06 .............................
# [CV] . var_smoothing=1.519911082952933e-06, score=0.415, total=   1.1s
# [CV] var_smoothing=1.519911082952933e-06 .............................
# [CV] . var_smoothing=1.519911082952933e-06, score=0.383, total=   1.1s
# [CV] var_smoothing=1.519911082952933e-06 .............................
# [CV] . var_smoothing=1.519911082952933e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-06 .............................
# [CV] . var_smoothing=1.519911082952933e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-06 .............................
# [CV] . var_smoothing=1.232846739442066e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-06 .............................
# [CV] . var_smoothing=1.232846739442066e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-06 .............................
# [CV] . var_smoothing=1.232846739442066e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-06 .............................
# [CV] . var_smoothing=1.232846739442066e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-06 .............................
# [CV] . var_smoothing=1.232846739442066e-06, score=0.384, total=   1.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.356, total=   1.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.415, total=   1.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.383, total=   1.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.340, total=   1.0s
# [CV] var_smoothing=1e-06 .............................................
# [CV] ................. var_smoothing=1e-06, score=0.384, total=   0.9s
# [CV] var_smoothing=8.111308307896872e-07 .............................
# ...
# [CV] . var_smoothing=8.111308307896873e-08, score=0.384, total=   0.9s
# [CV] var_smoothing=6.579332246575682e-08 .............................
# [CV] . var_smoothing=6.579332246575682e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-08 .............................
# [CV] . var_smoothing=6.579332246575682e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-08 .............................
# [CV] . var_smoothing=6.579332246575682e-08, score=0.383, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-08 .............................
# [CV] . var_smoothing=6.579332246575682e-08, score=0.340, total=   0.9s
# [CV] var_smoothing=6.579332246575682e-08 .............................
# [CV] . var_smoothing=6.579332246575682e-08, score=0.384, total=   0.9s
# [CV] var_smoothing=5.336699231206302e-08 .............................
# [CV] . var_smoothing=5.336699231206302e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-08 .............................
# [CV] . var_smoothing=5.336699231206302e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-08 .............................
# [CV] . var_smoothing=5.336699231206302e-08, score=0.383, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-08 .............................
# [CV] . var_smoothing=5.336699231206302e-08, score=0.340, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-08 .............................
# [CV] . var_smoothing=5.336699231206302e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=4.3287612810830526e-08 ............................
# [CV]  var_smoothing=4.3287612810830526e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=4.3287612810830526e-08 ............................
# [CV]  var_smoothing=4.3287612810830526e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=4.3287612810830526e-08 ............................
# [CV]  var_smoothing=4.3287612810830526e-08, score=0.383, total=   0.9s
# [CV] var_smoothing=4.3287612810830526e-08 ............................
# [CV]  var_smoothing=4.3287612810830526e-08, score=0.340, total=   0.9s
# [CV] var_smoothing=4.3287612810830526e-08 ............................
# [CV]  var_smoothing=4.3287612810830526e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=3.5111917342151277e-08 ............................
# [CV]  var_smoothing=3.5111917342151277e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=3.5111917342151277e-08 ............................
# [CV]  var_smoothing=3.5111917342151277e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=3.5111917342151277e-08 ............................
# [CV]  var_smoothing=3.5111917342151277e-08, score=0.383, total=   0.9s
# [CV] var_smoothing=3.5111917342151277e-08 ............................
# [CV]  var_smoothing=3.5111917342151277e-08, score=0.340, total=   1.0s
# [CV] var_smoothing=3.5111917342151277e-08 ............................
# [CV]  var_smoothing=3.5111917342151277e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-08 .............................
# [CV] . var_smoothing=2.848035868435799e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-08 .............................
# [CV] . var_smoothing=2.848035868435799e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-08 .............................
# [CV] . var_smoothing=2.848035868435799e-08, score=0.383, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-08 .............................
# [CV] . var_smoothing=2.848035868435799e-08, score=0.340, total=   1.0s
# [CV] var_smoothing=2.848035868435799e-08 .............................
# [CV] . var_smoothing=2.848035868435799e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-08 .............................
# [CV] . var_smoothing=2.310129700083158e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-08 .............................
# [CV] . var_smoothing=2.310129700083158e-08, score=0.415, total=   1.1s
# [CV] var_smoothing=2.310129700083158e-08 .............................
# [CV] . var_smoothing=2.310129700083158e-08, score=0.383, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-08 .............................
# [CV] . var_smoothing=2.310129700083158e-08, score=0.340, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-08 .............................
# [CV] . var_smoothing=2.310129700083158e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-08 .............................
# [CV] . var_smoothing=1.873817422860383e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-08 .............................
# [CV] . var_smoothing=1.873817422860383e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=1.873817422860383e-08 .............................
# [CV] . var_smoothing=1.873817422860383e-08, score=0.383, total=   0.9s
# [CV] var_smoothing=1.873817422860383e-08 .............................
# [CV] . var_smoothing=1.873817422860383e-08, score=0.340, total=   1.1s
# [CV] var_smoothing=1.873817422860383e-08 .............................
# [CV] . var_smoothing=1.873817422860383e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-08 .............................
# [CV] . var_smoothing=1.519911082952933e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-08 .............................
# [CV] . var_smoothing=1.519911082952933e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-08 .............................
# [CV] . var_smoothing=1.519911082952933e-08, score=0.383, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-08 .............................
# [CV] . var_smoothing=1.519911082952933e-08, score=0.340, total=   0.9s
# [CV] var_smoothing=1.519911082952933e-08 .............................
# [CV] . var_smoothing=1.519911082952933e-08, score=0.384, total=   0.9s
# [CV] var_smoothing=1.232846739442066e-08 .............................
# [CV] . var_smoothing=1.232846739442066e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-08 .............................
# [CV] . var_smoothing=1.232846739442066e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-08 .............................
# [CV] . var_smoothing=1.232846739442066e-08, score=0.383, total=   1.1s
# [CV] var_smoothing=1.232846739442066e-08 .............................
# [CV] . var_smoothing=1.232846739442066e-08, score=0.340, total=   1.0s
# [CV] var_smoothing=1.232846739442066e-08 .............................
# [CV] . var_smoothing=1.232846739442066e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.356, total=   1.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.415, total=   1.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.383, total=   1.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.340, total=   1.0s
# [CV] var_smoothing=1e-08 .............................................
# [CV] ................. var_smoothing=1e-08, score=0.384, total=   1.0s
# [CV] var_smoothing=8.111308307896856e-09 .............................
# [CV] . var_smoothing=8.111308307896856e-09, score=0.356, total=   0.9s
# [CV] var_smoothing=8.111308307896856e-09 .............................
# [CV] . var_smoothing=8.111308307896856e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=8.111308307896856e-09 .............................
# [CV] . var_smoothing=8.111308307896856e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=8.111308307896856e-09 .............................
# [CV] . var_smoothing=8.111308307896856e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=8.111308307896856e-09 .............................
# [CV] . var_smoothing=8.111308307896856e-09, score=0.384, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-09 .............................
# [CV] . var_smoothing=6.579332246575682e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-09 .............................
# [CV] . var_smoothing=6.579332246575682e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-09 .............................
# [CV] . var_smoothing=6.579332246575682e-09, score=0.383, total=   1.1s
# [CV] var_smoothing=6.579332246575682e-09 .............................
# [CV] . var_smoothing=6.579332246575682e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=6.579332246575682e-09 .............................
# [CV] . var_smoothing=6.579332246575682e-09, score=0.384, total=   0.9s
# [CV] var_smoothing=5.336699231206302e-09 .............................
# [CV] . var_smoothing=5.336699231206302e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-09 .............................
# [CV] . var_smoothing=5.336699231206302e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-09 .............................
# [CV] . var_smoothing=5.336699231206302e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-09 .............................
# [CV] . var_smoothing=5.336699231206302e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=5.336699231206302e-09 .............................
# [CV] . var_smoothing=5.336699231206302e-09, score=0.384, total=   1.0s
# [CV] var_smoothing=4.328761281083061e-09 .............................
# [CV] . var_smoothing=4.328761281083061e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=4.328761281083061e-09 .............................
# [CV] . var_smoothing=4.328761281083061e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=4.328761281083061e-09 .............................
# [CV] . var_smoothing=4.328761281083061e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=4.328761281083061e-09 .............................
# [CV] . var_smoothing=4.328761281083061e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=4.328761281083061e-09 .............................
# [CV] . var_smoothing=4.328761281083061e-09, score=0.384, total=   0.9s
# [CV] var_smoothing=3.5111917342151273e-09 ............................
# [CV]  var_smoothing=3.5111917342151273e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=3.5111917342151273e-09 ............................
# [CV]  var_smoothing=3.5111917342151273e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=3.5111917342151273e-09 ............................
# [CV]  var_smoothing=3.5111917342151273e-09, score=0.383, total=   0.9s
# [CV] var_smoothing=3.5111917342151273e-09 ............................
# [CV]  var_smoothing=3.5111917342151273e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=3.5111917342151273e-09 ............................
# [CV]  var_smoothing=3.5111917342151273e-09, score=0.384, total=   1.0s
# [CV] var_smoothing=2.848035868435805e-09 .............................
# [CV] . var_smoothing=2.848035868435805e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=2.848035868435805e-09 .............................
# [CV] . var_smoothing=2.848035868435805e-09, score=0.415, total=   0.9s
# [CV] var_smoothing=2.848035868435805e-09 .............................
# [CV] . var_smoothing=2.848035868435805e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=2.848035868435805e-09 .............................
# [CV] . var_smoothing=2.848035868435805e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=2.848035868435805e-09 .............................
# [CV] . var_smoothing=2.848035868435805e-09, score=0.384, total=   0.9s
# [CV] var_smoothing=2.310129700083158e-09 .............................
# [CV] . var_smoothing=2.310129700083158e-09, score=0.356, total=   0.9s
# [CV] var_smoothing=2.310129700083158e-09 .............................
# [CV] . var_smoothing=2.310129700083158e-09, score=0.415, total=   0.9s
# [CV] var_smoothing=2.310129700083158e-09 .............................
# [CV] . var_smoothing=2.310129700083158e-09, score=0.383, total=   0.9s
# [CV] var_smoothing=2.310129700083158e-09 .............................
# [CV] . var_smoothing=2.310129700083158e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=2.310129700083158e-09 .............................
# [CV] . var_smoothing=2.310129700083158e-09, score=0.384, total=   1.1s
# [CV] var_smoothing=1.873817422860387e-09 .............................
# [CV] . var_smoothing=1.873817422860387e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=1.873817422860387e-09 .............................
# [CV] . var_smoothing=1.873817422860387e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=1.873817422860387e-09 .............................
# [CV] . var_smoothing=1.873817422860387e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=1.873817422860387e-09 .............................
# [CV] . var_smoothing=1.873817422860387e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=1.873817422860387e-09 .............................
# [CV] . var_smoothing=1.873817422860387e-09, score=0.384, total=   1.1s
# [CV] var_smoothing=1.519911082952933e-09 .............................
# [CV] . var_smoothing=1.519911082952933e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-09 .............................
# [CV] . var_smoothing=1.519911082952933e-09, score=0.415, total=   1.1s
# [CV] var_smoothing=1.519911082952933e-09 .............................
# [CV] . var_smoothing=1.519911082952933e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-09 .............................
# [CV] . var_smoothing=1.519911082952933e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=1.519911082952933e-09 .............................
# [CV] . var_smoothing=1.519911082952933e-09, score=0.384, total=   1.0s
# [CV] var_smoothing=1.2328467394420635e-09 ............................
# [CV]  var_smoothing=1.2328467394420635e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=1.2328467394420635e-09 ............................
# [CV]  var_smoothing=1.2328467394420635e-09, score=0.415, total=   1.0s
# [CV] var_smoothing=1.2328467394420635e-09 ............................
# [CV]  var_smoothing=1.2328467394420635e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=1.2328467394420635e-09 ............................
# [CV]  var_smoothing=1.2328467394420635e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=1.2328467394420635e-09 ............................
# [CV]  var_smoothing=1.2328467394420635e-09, score=0.384, total=   1.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.356, total=   1.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.415, total=   0.9s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.383, total=   1.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.340, total=   1.0s
# [CV] var_smoothing=1e-09 .............................................
# [CV] ................. var_smoothing=1e-09, score=0.384, total=   1.0s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:  8.4min finished
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.84803587e-02, 2.31...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='f1', verbose=3)

# %%
#print best score obtained and the parameters which obtained it
print('F1 Score:', grid_NB.best_score_)
print('Best Hyperparameters:', grid_NB.best_params_)
print('Model object with best parameters: ')
print(grid_NB.best_estimator_)
# Out:
# F1 Score: 0.6514939902922656
# Best Hyperparameters: {'var_smoothing': 0.533669923120631}
# Model object with best parameters:
# GaussianNB(var_smoothing=0.533669923120631)

# %%
# train classifier
print("training...")
grid_NB.best_estimator_.fit(count_train.toarray(), y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
NB_test_preds = grid_NB.best_estimator_.predict(count_test.toarray())
print("complete.")

# save the model to disk
filename = 'grid_NB.sav'
pickle.dump(grid_NB.best_estimator_, open(filename, 'wb'))
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
grid_NB_precision = precision_score(y_test, NB_test_preds)
grid_NB_recall = recall_score(y_test, NB_test_preds)
grid_NB_f1_score = f1_score(y_test, NB_test_preds)
grid_NB_weighted_f1_score = f1_score(y_test, NB_test_preds, average='weighted')
grid_NB_macro_f1_score = f1_score(y_test, NB_test_preds, average='macro')
grid_NB_micro_f1_score = f1_score(y_test, NB_test_preds, average='micro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(grid_NB_precision))
print('Recall: {:.3}'.format(grid_NB_recall))
print('F1 Score: {:.3}'.format(grid_NB_f1_score))
print('Weighted F1 Score: {:.3}'.format(grid_NB_weighted_f1_score))
print('Macro F1 Score: {:.3}'.format(grid_NB_macro_f1_score))
print('Micro F1 Score: {:.3}'.format(grid_NB_micro_f1_score))

NB_metrics['Grid NB'] = {'precision': grid_NB_precision, 'recall': grid_NB_recall, 
                            'f1_score': grid_NB_f1_score, 'weighted_f1': grid_NB_weighted_f1_score,
                            'macro_f1': grid_NB_macro_f1_score, 'micro_f1': grid_NB_micro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.668
# Recall: 0.726
# F1 Score: 0.696
# Weighted F1 Score: 0.899
# Macro F1 Score: 0.817
# Micro F1 Score: 0.897

# %%
plot_confusion_matrix(grid_NB, count_test.toarray(), y_test)

# %% [markdown]
# ## Default NB with POS

# %%
X_train_pos, X_test_pos, y_train_pos, y_test_pos = train_test_split(df['pos_tags'], df['Hate'], test_size=0.25, random_state=12)
                                                       
count_train_pos = count.fit_transform(X_train_pos)
count_test_pos = count.transform(X_test_pos)

# %%
default_NB_POS = GaussianNB(var_smoothing=1e-9)

# %%
# train classifier
print("training...")
default_NB_POS.fit(count_train_pos.toarray(), y_train_pos)
print("complete.")
# use classifier to predict on test set
print("predicting...")
default_NB_POS_test_preds = default_NB_POS.predict(count_test_pos.toarray())
print("complete.")

# save the model to disk
filename = 'default_NB_POS.sav'
pickle.dump(default_NB_POS, open(filename, 'wb'))
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
default_NB_POS_precision = precision_score(y_test, default_NB_POS_test_preds)
default_NB_POS_recall = recall_score(y_test, default_NB_POS_test_preds)
default_NB_POS_f1_score = f1_score(y_test, default_NB_POS_test_preds)
default_NB_POS_weighted_f1_score = f1_score(y_test, default_NB_POS_test_preds, average='weighted')
default_NB_POS_macro_f1_score = f1_score(y_test, default_NB_POS_test_preds, average='macro')
default_NB_POS_micro_f1_score = f1_score(y_test, default_NB_POS_test_preds, average='micro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(default_NB_POS_precision))
print('Recall: {:.3}'.format(default_NB_POS_recall))
print('F1 Score: {:.3}'.format(default_NB_POS_f1_score))
print('Weighted F1 Score: {:.3}'.format(default_NB_POS_weighted_f1_score))
print('Macro F1 Score: {:.3}'.format(default_NB_POS_macro_f1_score))
print('Micro F1 Score: {:.3}'.format(default_NB_POS_micro_f1_score))

NB_metrics['Default NB with POS'] = {'precision': default_NB_POS_precision, 'recall': default_NB_POS_recall, 
                            'f1_score': default_NB_POS_f1_score, 'weighted_f1': default_NB_POS_weighted_f1_score,
                            'macro_f1': default_NB_POS_macro_f1_score, 'micro_f1': default_NB_POS_micro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.319
# Recall: 0.495
# F1 Score: 0.388
# Weighted F1 Score: 0.767
# Macro F1 Score: 0.614
# Micro F1 Score: 0.747

# %%
plot_confusion_matrix(default_NB_POS, count_test_pos.toarray(), y_test_pos)

# %% [markdown]
# ## Grid NB with POS

# %%
# train classifier
print("training...")
grid_NB.best_estimator_.fit(count_train_pos.toarray(), y_train_pos)
print("complete.")
# use classifier to predict on test set
print("predicting...")
NB_grid_POS_test_preds = grid_NB.best_estimator_.predict(count_test_pos.toarray())
print("complete.")

# save the model to disk
filename = 'grid_NB_pos.sav'
pickle.dump(grid_NB.best_estimator_, open(filename, 'wb'))
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
NB_grid_pos_precision = precision_score(y_test_pos, NB_grid_POS_test_preds)
NB_grid_pos_recall = recall_score(y_test_pos, NB_grid_POS_test_preds)
NB_grid_pos_f1_score = f1_score(y_test_pos, NB_grid_POS_test_preds)
NB_grid_pos_weighted_f1_score = f1_score(y_test_pos, NB_grid_POS_test_preds, average='weighted')
NB_grid_POS_macro_f1_score = f1_score(y_test, NB_grid_POS_test_preds, average='macro')
NB_grid_POS_micro_f1_score = f1_score(y_test, NB_grid_POS_test_preds, average='micro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(NB_grid_pos_precision))
print('Recall: {:.3}'.format(NB_grid_pos_recall))
print('F1 Score: {:.3}'.format(NB_grid_pos_f1_score))
print('Weighted F1 Score: {:.3}'.format(NB_grid_pos_weighted_f1_score))
print('Macro F1 Score: {:.3}'.format(NB_grid_POS_macro_f1_score))
print('Micro F1 Score: {:.3}'.format(NB_grid_POS_micro_f1_score))

NB_metrics['Grid Search NB with POS'] = {'precision': NB_grid_pos_precision, 'recall': NB_grid_pos_recall, 
                                  'f1_score': NB_grid_pos_f1_score, 'weighted_f1': NB_grid_pos_weighted_f1_score,
                        'macro_f1': NB_grid_POS_macro_f1_score, 'micro_f1': NB_grid_POS_micro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.776
# Recall: 0.375
# F1 Score: 0.506
# Weighted F1 Score: 0.863
# Macro F1 Score: 0.719
# Micro F1 Score: 0.881

# %%
plot_confusion_matrix(grid_NB.best_estimator_, count_test_pos.toarray(), y_test_pos)

# %%
#compare parameters
results = pd.DataFrame.from_dict(NB_metrics, orient='index')
results.to_csv(r"C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Results\NB_count_results",
               index=False)

# %%
results
# Out:
#                          precision    recall  f1_score  weighted_f1  macro_f1  \
# Default NB                0.307252  0.581227  0.401998     0.749707  0.609482
# Grid NB                   0.667774  0.725632  0.695502     0.898719  0.816765
# Default NB with POS       0.318605  0.494585  0.387553     0.766901  0.613917
# Grid Search NB with POS   0.776119  0.375451  0.506083     0.863377  0.719287
#
#                          micro_f1
# Default NB               0.719719
# Grid NB                  0.897016
# Default NB with POS      0.746635
# Grid Search NB with POS  0.881217

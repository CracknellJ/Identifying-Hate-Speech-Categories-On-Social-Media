# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, plot_confusion_matrix
import nltk

import pickle

# %%
#Load in data and split for train and test sets
df = pd.read_csv(r'C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Data\clean_dataset.csv')
X_train, X_test, y_train, y_test = train_test_split(df['text_lemma'], df['Annotation'], test_size=0.25, random_state=12)
                                                       
df.head(5)
# Out:
#              id                                               text Annotation  \
# 0  5.969655e+17  i just found the perfect rental why cant my le...    Neither
# 1  5.758918e+17   every time they discover anything its either ...    Neither
# 2  5.952595e+17    ok time to write code bbl\n\nmaking a new thing    Neither
# 3  5.723449e+17                            refined dessert not mkr    Neither
# 4  5.681320e+17    one of the best things anyone can do to impr...    Neither
#
#                                       tokenized_text  \
# 0  ['found', 'perfect', 'rental', 'cant', 'lease'...
# 1  ['every', 'time', 'discover', 'anything', 'eit...
# 2  ['ok', 'time', 'write', 'code', 'bbl', 'making...
# 3                      ['refined', 'dessert', 'mkr']
# 4  ['one', 'best', 'things', 'anyone', 'improve',...
#
#                                           text_lemma  \
# 0  ['found', 'perfect', 'rental', 'cant', 'lease'...
# 1  ['every', 'time', 'discover', 'anything', 'eit...
# 2  ['ok', 'time', 'write', 'code', 'bbl', 'making...
# 3                      ['refined', 'dessert', 'mkr']
# 4  ['one', 'best', 'thing', 'anyone', 'improve', ...
#
#                                             pos_tags  Hate
# 0  ['i_NN', 'just_RB', 'found_VBD', 'the_DT', 'pe...     0
# 1  ['every_DT', 'time_NN', 'they_PRP', 'discover_...     0
# 2  ['ok_JJ', 'time_NN', 'to_TO', 'write_VB', 'cod...     0
# 3  ['refined_VBN', 'dessert_NN', 'not_RB', 'mkr_VB']     0
# 4  ['one_CD', 'of_IN', 'the_DT', 'best_JJS', 'thi...     0

# %%
#create count matrix
counts = CountVectorizer()
count_train = counts.fit_transform(X_train)
count_test = counts.transform(X_test)

# %% [markdown]
# ## Default

# %%
SVM_default = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# %%
# train classifier
print("training...")
SVM_default.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_default.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_metrics = {}
SVM_default_precision = precision_score(y_test, SVM_test_preds, average='macro')
SVM_default_recall = recall_score(y_test, SVM_test_preds, average='macro')
SVM_default_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_default_precision))
print('Recall: {:.3}'.format(SVM_default_recall))
print('Macro F1 Score: {:.3}'.format(SVM_default_macro_f1_score))

SVM_metrics['Default SVM'] = {'precision': SVM_default_precision, 'recall': SVM_default_recall, 
                              'macro_f1': SVM_default_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.814
# Recall: 0.506
# Macro F1 Score: 0.578

# %%
plot_confusion_matrix(SVM_default, count_test, y_test)

# %% [markdown]
# ## Grid

# %%
SVM_default_grid = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# dictionary containing the parameters which will be used for grid search
grid_search_params={'C': [1, 10, 30],  
              'gamma': ['auto', 0.1, 0.01], 
              'kernel': ['rbf', 'sigmoid', 'linear', 'poly'],
              'coef0': [0.1, 1, 3],
              'degree': [1, 3, 5],
              'class_weight': [None, 'balanced']}

# grid search with f1 being the performance metric
SVM_grid = GridSearchCV(SVM_default_grid, grid_search_params, cv=5, scoring='f1_macro', verbose=3)
SVM_grid.fit(count_train, y_train)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.493, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.536, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.636, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.574, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.508, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.563, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.625, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.661, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.594, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.621, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.709, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.672, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.712, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.569, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.626, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.662, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.597, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.655, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.398, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.405, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.408, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.396, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.377, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.398, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.405, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.408, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.396, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.377, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.709, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.672, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.652, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.712, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.398, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.405, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.408, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.396, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.377, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.493, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.536, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.636, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.574, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.508, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.563, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.625, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.661, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.594, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.621, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.403, total=   2.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.411, total=   2.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.398, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.464, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.418, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.398, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.405, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.408, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.396, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.377, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.398, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.405, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.408, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.396, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.377, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.712, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.493, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.536, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.636, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.574, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.508, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.563, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.625, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.661, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.594, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.621, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.257, total=   2.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.296, total=   2.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.305, total=   2.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.299, total=   2.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.298, total=   2.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.398, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.405, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.408, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.396, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.377, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.398, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.405, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.408, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.396, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.377, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.493, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.536, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.636, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.574, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.508, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.461, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.403, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.567, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.490, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.517, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.697, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.569, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.626, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.662, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.597, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.655, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.398, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.405, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.408, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.396, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.377, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.232, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.232, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.250, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.709, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.672, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.398, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.405, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.408, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.396, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.377, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.697, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.709, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.672, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.652, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.712, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.493, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.536, total=   1.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.636, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.574, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.508, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.461, total=   0.7s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.403, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# ...
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.629, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.626, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.607, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.660, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.731, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.756, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.742, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.707, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.713, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.651, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.699, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.738, total=   3.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.677, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.662, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.633, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.611, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.615, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.591, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.656, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.675, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.686, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.627, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.626, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.680, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.701, total=   2.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.714, total=   2.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.743, total=   2.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.699, total=   2.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.687, total=   2.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.007, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.007, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.006, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.633, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.611, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.615, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.591, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.656, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.715, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.740, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.728, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.678, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.693, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.571, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.533, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.638, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.538, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.607, total=   1.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.649, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.690, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.657, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.670, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.637, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.633, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.611, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.615, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.591, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.656, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.569, total=   0.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.638, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.660, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.585, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.628, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.731, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.756, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.742, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.707, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.713, total=   0.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.651, total=   3.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.699, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.738, total=   3.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.677, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.662, total=   3.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.633, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.611, total=   0.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.615, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.591, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.656, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.577, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.627, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.628, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.604, total=   0.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.667, total=   0.7s
# [Parallel(n_jobs=1)]: Done 3240 out of 3240 | elapsed: 70.4min finished
# GridSearchCV(cv=5, estimator=SVC(random_state=12),
#              param_grid={'C': [1, 10, 30], 'class_weight': [None, 'balanced'],
#                          'coef0': [0.1, 1, 3], 'degree': [1, 3, 5],
#                          'gamma': ['auto', 0.1, 0.01],
#                          'kernel': ['rbf', 'sigmoid', 'linear', 'poly']},
#              scoring='f1_macro', verbose=3)

# %%
# train classifier
print("training...")
SVM_grid.best_estimator_.fit(count_train, y_train)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds = SVM_grid.best_estimator_.predict(count_test)
print("complete.")
# Out:
# training...
# complete.
# predicting...
# complete.

# %%
SVM_grid_precision = precision_score(y_test, SVM_test_preds, average='macro') 
SVM_grid_recall = recall_score(y_test, SVM_test_preds, average='macro')
SVM_grid_macro_f1_score = f1_score(y_test, SVM_test_preds, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_grid_precision))
print('Recall: {:.3}'.format(SVM_grid_recall))
print('Macro F1 Score: {:.3}'.format(SVM_grid_macro_f1_score))

SVM_metrics['Grid Search SVM'] = {'precision': SVM_grid_precision, 'recall': SVM_grid_recall, 
                                  'macro_f1': SVM_grid_macro_f1_score}
# Out:
# Model evaluation metrics
# Precision: 0.77
# Recall: 0.744
# Macro F1 Score: 0.747

# %%
plot_confusion_matrix(SVM_grid.best_estimator_, count_test, y_test)

# %%
#compare parameters
results = pd.DataFrame.from_dict(SVM_metrics, orient='index')
results.to_csv(r"C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Results\SVM_count_results_multi",
               index=False)
results
# Out:
#                  precision    recall  macro_f1
# Default SVM       0.813699  0.505804  0.578060
# Grid Search SVM   0.769781  0.744036  0.747218

# %%
X_train_pos, X_test_pos, y_train_pos, y_test_pos = train_test_split(df['pos_tags'], df['Annotation'], test_size=0.25, random_state=12)
                                                       
count_train_pos = counts.fit_transform(X_train_pos)
count_test_pos = counts.transform(X_test_pos)

SVM_grid_pos = svm.SVC(C=1.0, kernel='rbf', gamma='scale', shrinking=True,
                      class_weight=None, random_state=12)

# dictionary containing the parameters which will be used for grid search
grid_search_params={'C': [1, 10, 30],  
              'gamma': ['auto', 0.1, 0.01], 
              'kernel': ['rbf', 'sigmoid', 'linear', 'poly'],
              'coef0': [0.1, 1, 3],
              'degree': [1, 3, 5],
              'class_weight': [None, 'balanced']}

# grid search with f1 being the performance metric
SVM_grid_pos = GridSearchCV(SVM_grid_pos, grid_search_params, cv=5, scoring='f1_macro', verbose=3)
SVM_grid_pos.fit(count_train_pos, y_train_pos)

# train classifier
print("training...")
SVM_grid_pos.best_estimator_.fit(count_train_pos, y_train_pos)
print("complete.")
# use classifier to predict on test set
print("predicting...")
SVM_test_preds_pos = SVM_grid_pos.best_estimator_.predict(count_test_pos)
print("complete.")

SVM_grid_pos_precision = precision_score(y_test_pos, SVM_test_preds_pos, average='macro')
SVM_grid_pos_recall = recall_score(y_test_pos, SVM_test_preds_pos, average='macro')
SVM_grid_pos_macro_f1_score = f1_score(y_test_pos, SVM_test_preds_pos, average='macro')

#model evaluation
print('Model evaluation metrics')
print('Precision: {:.3}'.format(SVM_grid_pos_precision))
print('Recall: {:.3}'.format(SVM_grid_pos_recall))
print('Macro F1 Score: {:.3}'.format(SVM_grid_pos_macro_f1_score))

SVM_metrics['Grid Search SVM with POS'] = {'precision': SVM_grid_pos_precision, 'recall': SVM_grid_pos_recall, 
                                           'macro_f1': SVM_grid_pos_macro_f1_score}

plot_confusion_matrix(SVM_grid_pos.best_estimator_, count_test_pos, y_test_pos)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.637, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.358, total=   4.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.401, total=   3.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.416, total=   3.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.388, total=   3.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=rbf, score=0.350, total=   3.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.363, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.414, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.493, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.441, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=sigmoid, score=0.555, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.432, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.443, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.563, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.522, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.1, kernel=poly, score=0.562, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.385, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.401, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.404, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.395, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=rbf, score=0.379, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.321, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.253, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.239, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.288, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=sigmoid, score=0.322, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.326, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.263, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.246, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.307, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=1, gamma=0.01, kernel=poly, score=0.331, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.358, total=   4.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.401, total=   3.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.416, total=   3.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.388, total=   4.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=rbf, score=0.350, total=   4.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.363, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.414, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.493, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.441, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=sigmoid, score=0.555, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.353, total=   4.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.358, total=   4.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.407, total=   4.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.348, total=   4.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.1, kernel=poly, score=0.348, total=   4.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.385, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.401, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.404, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.395, total=   1.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=rbf, score=0.379, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.321, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.253, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.239, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.288, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=sigmoid, score=0.322, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   2.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   2.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   2.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   2.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=3, gamma=0.01, kernel=poly, score=0.228, total=   2.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=auto, kernel=poly, score=0.228, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.358, total=   3.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.401, total=   3.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.416, total=   3.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.388, total=   3.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=rbf, score=0.350, total=   4.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.363, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.414, total=   0.9s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.493, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.441, total=   0.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=sigmoid, score=0.555, total=   0.8s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.637, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=linear, score=0.683, total=   1.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.280, total=   5.6s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.324, total=   6.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.361, total=   5.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.321, total=   7.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.1, kernel=poly, score=0.315, total=   5.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.385, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.401, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.404, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.395, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=rbf, score=0.379, total=   1.7s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.321, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.253, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.239, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.288, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=sigmoid, score=0.322, total=   1.5s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   2.3s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   2.0s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   2.1s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   2.2s
# [CV] C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=0.1, degree=5, gamma=0.01, kernel=poly, score=0.228, total=   1.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=auto, kernel=poly, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.358, total=   4.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.401, total=   3.8s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.416, total=   4.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.388, total=   4.0s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=rbf, score=0.350, total=   4.1s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.343, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.370, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.358, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.363, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=sigmoid, score=0.341, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.432, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.443, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.563, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.522, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.1, kernel=poly, score=0.562, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.385, total=   1.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.401, total=   1.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.404, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.395, total=   1.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=rbf, score=0.379, total=   1.7s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=sigmoid, score=0.228, total=   1.3s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.599, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.589, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.637, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.326, total=   1.6s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.263, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.246, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.307, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=1, gamma=0.01, kernel=poly, score=0.331, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=rbf, score=0.228, total=   1.2s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   1.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=sigmoid, score=0.228, total=   0.8s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.579, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.599, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.589, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.637, total=   1.5s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=linear, score=0.683, total=   1.4s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=auto, kernel=poly, score=0.228, total=   1.1s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.358, total=   4.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.401, total=   4.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.416, total=   4.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.388, total=   4.0s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=rbf, score=0.350, total=   4.2s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.343, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid, score=0.370, total=   0.9s
# [CV] C=1, class_weight=None, coef0=1, degree=3, gamma=0.1, kernel=sigmoid
# ...
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.547, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.577, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.593, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.539, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.1, kernel=poly, score=0.595, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.650, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.600, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.632, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.623, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=rbf, score=0.723, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.592, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.531, total=   4.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.544, total=   4.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.537, total=   4.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=sigmoid, score=0.535, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.545, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.578, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.598, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.607, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=linear, score=0.616, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.577, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.573, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.599, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.624, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=3, gamma=0.01, kernel=poly, score=0.636, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.638, total=   4.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.579, total=   4.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.638, total=   4.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.605, total=   4.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=rbf, score=0.623, total=   4.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.007, total=   5.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.007, total=   5.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   5.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.228, total=   5.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=sigmoid, score=0.006, total=   5.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.545, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.578, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.598, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.607, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=linear, score=0.616, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.626, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.614, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.612, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.664, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=auto, kernel=poly, score=0.679, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.453, total=   3.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.440, total=   4.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.477, total=   4.1s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.384, total=   4.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=rbf, score=0.458, total=   3.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.464, total=   3.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.451, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.432, total=   3.7s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.433, total=   3.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=sigmoid, score=0.440, total=   3.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.545, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.578, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.598, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.607, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=linear, score=0.616, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.496, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.577, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.590, total=   1.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.511, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.1, kernel=poly, score=0.541, total=   1.8s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.650, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.600, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.632, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.623, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=rbf, score=0.723, total=   1.6s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.592, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.531, total=   4.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.544, total=   4.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.537, total=   4.9s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=sigmoid, score=0.535, total=   5.0s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.545, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.578, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.598, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.607, total=   1.2s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=linear, score=0.616, total=   1.3s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.545, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.583, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.600, total=   1.5s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.578, total=   1.4s
# [CV] C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly
# [CV]  C=30, class_weight=balanced, coef0=3, degree=5, gamma=0.01, kernel=poly, score=0.618, total=   1.4s
# [Parallel(n_jobs=1)]: Done 3240 out of 3240 | elapsed: 132.1min finished
# training...
# complete.
# predicting...
# complete.
# Model evaluation metrics
# Precision: 0.821
# Recall: 0.592
# Macro F1 Score: 0.639

# %%
plot_confusion_matrix(SVM_grid_pos, count_test_pos, y_test_pos)

# %%
#compare parameters
results = pd.DataFrame.from_dict(SVM_metrics, orient='index')
results.to_csv(r"C:\Users\jackc\Semester2\Project\Identifying-Hate-Speech-Categories-On-Social-Media\Results\SVM_count_results_multi.csv",
               index=True)
results
# Out:
#                           precision    recall  macro_f1
# Default SVM                0.813699  0.505804  0.578060
# Grid Search SVM            0.769781  0.744036  0.747218
# Grid Search SVM with POS   0.821476  0.592366  0.638556
